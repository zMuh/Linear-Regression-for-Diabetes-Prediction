# %% [markdown]
# # Linear Regression for Diabetes Prediction

# %% [markdown]
# ## Data Description
# The "Diabetes" dataset is a built-in dataset in scikit-learn that consists of physiological and diagnostic measurements related to diabetes disease. It comprises ten numerical features, including:
#
# - Age: Age in years.
# - Sex: Male (1) or female (0).
# - Body Mass Index (BMI): Body mass index, which relates weight to height.
# - Average Blood Pressure (BP): Mean arterial blood pressure.
# - S1 to S6: Six blood serum measurements. These are numerical features representing various biochemical markers.

# %%
import pandas as pd
from sklearn.datasets import load_diabetes

data = load_diabetes()

# %% [markdown]
# The target variable is a quantitative measure of disease progression one year after the baseline measurements were taken. It represents a numerical value indicating the severity or progression of diabetes disease.

# %%
df = pd.DataFrame(data.data,columns=data.feature_names)
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()
# here we can see the realtion more presice and the strong correlation between blood serum measurements, blood pressure

# %%
# we can also see positive relation for BMI and Blood Pressure and that's reason for using regression
plt.scatter(df['bmi'],df['bp'])
plt.xlabel('BMI')
plt.ylabel('Blood Pressure')
plt.title('Correlation between bmi and bp')
plt.show()

# %%
# postive strong realtion
plt.scatter(df['s1'],df['s2'])
plt.xlabel('s1')
plt.ylabel('s2')
plt.title('Correlation between s1,s2')
plt.show()

# %% [markdown]
# ## Split Data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = df
y = data.target

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Accuracy

# %%
from sklearn.metrics import r2_score
predictions = model.predict(x_test)
print("R-Squared Score:",r2_score(y_test,predictions))
acc=model.score(x_test,y_test)
print("Accuracy:",acc*100) # its the better the closest to 0
# Out:
# R-Squared Score: 0.4526027629719195
# Accuracy: 45.26027629719195
